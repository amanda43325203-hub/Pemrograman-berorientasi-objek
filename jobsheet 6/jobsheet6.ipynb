# %% [markdown]
# ## PRAKTIKUM 1

# %%
from abc import ABC, abstractmethod

class KendaraanAbstrak(ABC):

    def __init__(self, merk):
        self.merk = merk
        print(f"Inisialisasi KendaraanAbstrak dengan merk: {self.merk}")

    def info_merk(self):
        print(f"Merk kendaraan ini adalah {self.merk}.")

    @abstractmethod
    def start_mesin(self):
        print(f"Mesin mobil {self.merk} dinyalakan.")

    @abstractmethod
    def stop_mesin(self):
        print(f"Mesin mobil {self.merk} dimatikan.")


class Mobil(KendaraanAbstrak):

    def start_mesin(self):
        print(f"Mesin mobil {self.merk} dinyalakan.")

    def stop_mesin(self):
        print(f"Mesin mobil {self.merk} dimatikan.")


if __name__ == "__main__":
    mobil_contoh = Mobil("Toyota")
    mobil_contoh.start_mesin()
    mobil_contoh.info_merk()
    mobil_contoh.stop_mesin()
# Out:
# Inisialisasi KendaraanAbstrak dengan merk: Toyota
# Mesin mobil Toyota dinyalakan.
# Merk kendaraan ini adalah Toyota.
# Mesin mobil Toyota dimatikan.

# %% [markdown]
# ## PRAKTIKUM 2

# %%
from abc import ABC, abstractmethod

# Definisikan kelas abstrak
class MediaAbstrak(ABC):
    def __init__(self, judul):
        self.judul = judul
        print(f"Inisialisasi MediaAbstrak dengan judul: {self.judul}")

    @abstractmethod
    def play(self):
        """Metode abstrak untuk memulai pemutaran."""
        pass

    @abstractmethod
    def stop(self):
        """Metode abstrak untuk menghentikan pemutaran."""
        pass

# Kode Utama
if __name__ == "__main__":
    print("Mencoba membuat objek dari kelas abstrak MediaAbstrak...")
    
    # Blok try-except untuk menangkap error yang diharapkan
    try:
        media = MediaAbstrak("Konten Abstrak")
        print("Objek berhasil dibuat (SEHARUSNYA TIDAK TERJADI).")
        media.play()
    except TypeError as e:
        print(f"\nGAGAL membuat objek!")
        print(f"Error yang muncul (sesuai harapan): {e}")
# Out:
# Mencoba membuat objek dari kelas abstrak MediaAbstrak...
#
# GAGAL membuat objek!
# Error yang muncul (sesuai harapan): Can't instantiate abstract class MediaAbstrak with abstract methods play, stop

# %% [markdown]
# ## PRAKTIKUM 3

# %%
from abc import ABC, abstractmethod
import locale
import random

# Setting locale Indonesia
try:
    locale.setlocale(locale.LC_ALL, 'id_ID.UTF-8')
except locale.Error:
    print("Locale id_ID.UTF-8 tidak tersedia, gunakan locale default.")

def format_rupiah(angka):
    return locale.currency(angka, grouping=True, symbol='Rp')

# Kelas Abstrak
class AlatPembayaranAbstrak(ABC):
    def __init__(self, nama_metode):
        self.nama_metode = nama_metode
        print(f"Inisialisasi alat pembayaran: {self.nama_metode}")

    def info(self):
        print(f"Metode Pembayaran: {self.nama_metode}")

    @abstractmethod
    def proses_pembayaran(self, jumlah):
        pass

# Implementasi Subclass Konkret
class KartuKredit(AlatPembayaranAbstrak):
    def __init__(self, nomor_kartu, nama_pemilik):
        super().__init__("Kartu Kredit")
        self.nomor_kartu = nomor_kartu[-4:]
        self.nama_pemilik = nama_pemilik
        print(f" -> Kartu Kredit ************{self.nomor_kartu} ({self.nama_pemilik}) siap.")

    def proses_pembayaran(self, jumlah):
        print(f" Memproses pembayaran {format_rupiah(jumlah)} via Kartu Kredit ************{self.nomor_kartu}...")
        berhasil = random.choice([True, False])
        if berhasil:
            print(" Pembayaran Kartu Kredit Berhasil.")
            return True
        else:
            print(" Pembayaran Kartu Kredit Gagal (Limit tidak cukup/Error).")
            return False

class DompetDigital(AlatPembayaranAbstrak):
    def __init__(self, nomor_telepon, nama_provider):
        super().__init__(f"Dompet Digital ({nama_provider})")
        self.nomor_telepon = nomor_telepon
        self._saldo = random.randint(50000, 500000)
        print(f" -> Dompet Digital {self.nomor_telepon} siap (Saldo: {format_rupiah(self._saldo)}).")

    def proses_pembayaran(self, jumlah):
        print(f" Memproses pembayaran {format_rupiah(jumlah)} via Dompet Digital {self.nomor_telepon}...")
        if jumlah < self._saldo:
            self._saldo -= jumlah
            print(" Pembayaran Dompet Digital Berhasil.")
            print(f" Saldo tersisa: {format_rupiah(self._saldo)}")
            return True
        else:
            print(" Pembayaran Dompet Digital Gagal (Saldo tidak mencukupi).")
            print(f" Saldo saat ini: {format_rupiah(self._saldo)}")
            return False

# Kode Utama
if __name__ == "__main__":
    print("\nMembuat Objek Alat Pembayaran...")
    kartu_bca = KartuKredit("1234-5678-9012-3456", "Budi Cahyono")
    gopay = DompetDigital("08123456789", "GoPay")

    print("\nMelakukan Pembayaran:")
    print("\nMencoba bayar dengan Kartu Kredit:")
    kartu_bca.info()
    status_kk = kartu_bca.proses_pembayaran(150000)
    print(f" Status Transaksi KK: {'Sukses' if status_kk else 'Gagal'}")

    print("\nMencoba bayar dengan GoPay (Jumlah Kecil):")
    gopay.info()
    status_gopay1 = gopay.proses_pembayaran(75000)
    print(f" Status Transaksi GoPay 1: {'Sukses' if status_gopay1 else 'Gagal'}")
# Out:
# Membuat Objek Alat Pembayaran...
# Inisialisasi alat pembayaran: Kartu Kredit
#  -> Kartu Kredit ************3456 (Budi Cahyono) siap.
# Inisialisasi alat pembayaran: Dompet Digital (GoPay)
#  -> Dompet Digital 08123456789 siap (Saldo: Rp165.801,00).
#
# Melakukan Pembayaran:
#
# Mencoba bayar dengan Kartu Kredit:
# Metode Pembayaran: Kartu Kredit
#  Memproses pembayaran Rp150.000,00 via Kartu Kredit ************3456...
#  Pembayaran Kartu Kredit Gagal (Limit tidak cukup/Error).
#  Status Transaksi KK: Gagal
#
# Mencoba bayar dengan GoPay (Jumlah Kecil):
# Metode Pembayaran: Dompet Digital (GoPay)
#  Memproses pembayaran Rp75.000,00 via Dompet Digital 08123456789...
#  Pembayaran Dompet Digital Berhasil.
#  Saldo tersisa: Rp90.801,00
#  Status Transaksi GoPay 1: Sukses

# %% [markdown]
# ## PRAKTIKUM 4

# %%
from abc import ABC, abstractmethod
import time

# Kelas Abstrak
class DokumenAbstrak(ABC):
    def __init__(self, nama_file):
        self.nama_file = nama_file
        print(f"Inisialisasi Dokumen: {self.nama_file}")

    def info_file(self):
        print(f"Nama File: {self.nama_file}")

    @abstractmethod
    def cetak(self):
        pass

    @abstractmethod
    def simpan(self):
        pass

# Subclass Konkret 1
class DokumenTeks(DokumenAbstrak):
    def __init__(self, nama_file, isi_teks):
        super().__init__(nama_file)
        self.isi_teks = isi_teks
        print(" -> Tipe: Dokumen Teks")

    def cetak(self):
        print(f"Mencetak Dokumen Teks '{self.nama_file}':")
        print("="*15)
        print(self.isi_teks)
        print("="*15)

    def simpan(self):
        print(f"Menyimpan Dokumen Teks '{self.nama_file}' ke disk...")
        time.sleep(0.2)
        print(" -> Berhasil disimpan.")

# Subclass Konkret 2
class Spreadsheet(DokumenAbstrak):
    def __init__(self, nama_file, jumlah_baris, jumlah_kolom):
        super().__init__(nama_file)
        self.baris = jumlah_baris
        self.kolom = jumlah_kolom
        print(" -> Tipe: Spreadsheet")

    def cetak(self):
        print(f"Mencetak Spreadsheet '{self.nama_file}' ({self.baris} baris x {self.kolom} kolom)...")
        print(" (Menampilkan pratinjau...)")

    def simpan(self):
        print(f"Menyimpan Spreadsheet '{self.nama_file}' ke format .xlsx...")
        time.sleep(0.3)
        print(" -> Berhasil disimpan.")

# Fungsi Polimorfik
def proses_dokumen(daftar_dokumen):
    print("\n======= MEMPROSES SEMUA DOKUMEN =======")
    for doc in daftar_dokumen:
        print(f"\n--- Memproses {type(doc).__name__}: {doc.nama_file} ---")
        try:
            doc.cetak()
            doc.simpan()
        except Exception as e:
            print(f" Error saat memproses {doc.nama_file}: {e}")

# Kode Utama
if __name__ == "__main__":
    print("Membuat Dokumen...")
    dok1 = DokumenTeks("laporan.txt", "Ini adalah isi laporan singkat.")
    dok2 = Spreadsheet("data_penjualan.xlsx", 200, 15)
    dok3 = DokumenTeks("catatan_rapat.txt", "Poin penting:\n- Bahas budget\n- Tentukan timeline")

    koleksi_dokumen = [dok1, dok2, dok3]
    
    # Memanggil fungsi polimorfik
    proses_dokumen(koleksi_dokumen)
    print("\n======= SELESAI MEMPROSES DOKUMEN =======")
# Out:
# Membuat Dokumen...
# Inisialisasi Dokumen: laporan.txt
#  -> Tipe: Dokumen Teks
# Inisialisasi Dokumen: data_penjualan.xlsx
#  -> Tipe: Spreadsheet
# Inisialisasi Dokumen: catatan_rapat.txt
#  -> Tipe: Dokumen Teks
#
# ======= MEMPROSES SEMUA DOKUMEN =======
#
# --- Memproses DokumenTeks: laporan.txt ---
# Mencetak Dokumen Teks 'laporan.txt':
# ===============
# Ini adalah isi laporan singkat.
# ===============
# Menyimpan Dokumen Teks 'laporan.txt' ke disk...
#  -> Berhasil disimpan.
#
# --- Memproses Spreadsheet: data_penjualan.xlsx ---
# Mencetak Spreadsheet 'data_penjualan.xlsx' (200 baris x 15 kolom)...
#  (Menampilkan pratinjau...)
# Menyimpan Spreadsheet 'data_penjualan.xlsx' ke format .xlsx...
#  -> Berhasil disimpan.
#
# --- Memproses DokumenTeks: catatan_rapat.txt ---
# Mencetak Dokumen Teks 'catatan_rapat.txt':
# ===============
# Poin penting:
# - Bahas budget
# - Tentukan timeline
# ===============
# Menyimpan Dokumen Teks 'catatan_rapat.txt' ke disk...
#  -> Berhasil disimpan.
#
# ======= SELESAI MEMPROSES DOKUMEN =======

# %% [markdown]
# ## PRAKTIKUM 5

# %%
from abc import ABC, abstractmethod
import math

# Kelas Abstrak
class BangunDatarAbstrak(ABC):
    def __init__(self, nama):
        self._nama = nama
        print(f"Inisialisasi BangunDatarAbstrak: {self._nama}")

    # Metode Konkret
    @property
    def nama(self):
        return self._nama

    def info_lengkap(self):
        print(f"\n--- Info Lengkap: {self.nama} ---")
        try:
            luas = self.hitung_luas()
            print(f" Luas : {luas:.2f}")
        except NotImplementedError:
            print(" Luas : Belum diimplementasikan.")
        
        try:
            keliling = self.hitung_keliling()
            print(f" Keliling : {keliling:.2f}")
        except NotImplementedError:
            print(" Keliling : Belum diimplementasikan.")
        print("-" * (len(self.nama) + 18))

    # Metode Abstrak
    @abstractmethod
    def hitung_luas(self):
        pass

    @abstractmethod
    def hitung_keliling(self):
        pass

# Subclass Konkret
class Lingkaran(BangunDatarAbstrak):
    def __init__(self, radius):
        super().__init__("Lingkaran")
        if radius < 0:
            raise ValueError("Radius tidak boleh negatif")
        self.radius = radius
        print(f" -> Lingkaran dibuat (Radius: {self.radius}).")

    def hitung_luas(self):
        return math.pi * (self.radius ** 2)

    def hitung_keliling(self):
        return 2 * math.pi * self.radius

# Kode Utama
if __name__ == "__main__":
    print("Membuat objek Lingkaran...")
    lingkaran_A = Lingkaran(10)
    
    # Memanggil metode konkret
    print(f"\nNama bangun (via property): {lingkaran_A.nama}")
    lingkaran_A.info_lengkap()
# Out:
# Membuat objek Lingkaran...
# Inisialisasi BangunDatarAbstrak: Lingkaran
#  -> Lingkaran dibuat (Radius: 10).
#
# Nama bangun (via property): Lingkaran
#
# --- Info Lengkap: Lingkaran ---
#  Luas : 314.16
#  Keliling : 62.83
# ---------------------------

# %% [markdown]
# ## PRAKTIKUM 6

# %%
from abc import ABC, abstractmethod

# Kelas Abstrak
class ElemenGrafis(ABC):
    def __init__(self, id_elemen, warna):
        print(f" [ElemenGrafis __init__] Membuat elemen dengan ID: {id_elemen}")
        self._id = id_elemen
        self.warna = warna

    @property
    def id_elemen(self):
        print(f" [ElemenGrafis id_elemen getter] Mengakses ID: {self._id}")
        return self._id

    # Getter abstrak
    @property
    @abstractmethod
    def posisi(self):
        pass

    # Setter abstrak
    @posisi.setter
    @abstractmethod
    def posisi(self, koordinat_baru):
        pass

    # Metode Abstrak
    @abstractmethod
    def gambar(self):
        pass

    # Metode Konkret
    def info_warna(self):
        print(f" [ElemenGrafis info_warna] Warna elemen {self.id_elemen}: {self.warna}")

# Subclass Konkret
class Kotak(ElemenGrafis):
    def __init__(self, id_elemen, warna, x=0, y=0, lebar=10, tinggi=10):
        super().__init__(id_elemen, warna)
        print(f" [Kotak __init__] Menginisialisasi Kotak ID: {self.id_elemen}")
        self._x = x
        self._y = y
        self.lebar = lebar
        self.tinggi = tinggi

    @property
    def posisi(self):
        print(f" [Kotak posisi getter] Mengembalikan posisi Kotak {self.id_elemen}: ({self._x}, {self._y})")
        return (self._x, self._y)

    @posisi.setter
    def posisi(self, koordinat_baru):
        print(f" [Kotak posisi setter] Mencoba set posisi Kotak {self.id_elemen} ke {koordinat_baru}")
        if isinstance(koordinat_baru, tuple) and len(koordinat_baru) == 2:
            self._x = koordinat_baru[0]
            self._y = koordinat_baru[1]
            print(f" -> Posisi Kotak {self.id_elemen} berhasil diubah ke ({self._x}, {self._y})")
        else:
            print(" -> Gagal: Posisi harus berupa tuple (x, y).")

    def gambar(self):
        print(f" [Kotak gambar] Menggambar Kotak '{self.id_elemen}' warna {self.warna} "
              f"dengan ukuran {self.lebar}x{self.tinggi} di ({self._x}, {self._y})")

# Kode Utama
if __name__ == "__main__":
    print("Membuat objek Kotak...")
    kotak1 = Kotak("KotakA", "Merah", x=5, y=10, lebar=20)
    print("-" * 30)

    print("Mengakses ID...")
    id_ktk = kotak1.id_elemen
    print("-" * 30)

    print("Mengakses Posisi Awal...")
    pos_awal = kotak1.posisi
    print("-" * 30)

    print("Mengubah Posisi...")
    kotak1.posisi = (50, 60)
    print("Mengakses Posisi Baru...")
    pos_baru = kotak1.posisi
    print("-" * 30)

    print("Mencoba Set Posisi Salah...")
    kotak1.posisi = [100, 200]
    print("-" * 30)

    print("Menggambar Kotak...")
    kotak1.gambar()
    print("-" * 30)

    print("Info Warna...")
    kotak1.info_warna()
    print("-" * 30)
# Out:
# Membuat objek Kotak...
#  [ElemenGrafis __init__] Membuat elemen dengan ID: KotakA
#  [ElemenGrafis id_elemen getter] Mengakses ID: KotakA
#  [Kotak __init__] Menginisialisasi Kotak ID: KotakA
# ------------------------------
# Mengakses ID...
#  [ElemenGrafis id_elemen getter] Mengakses ID: KotakA
# ------------------------------
# Mengakses Posisi Awal...
#  [ElemenGrafis id_elemen getter] Mengakses ID: KotakA
#  [Kotak posisi getter] Mengembalikan posisi Kotak KotakA: (5, 10)
# ------------------------------
# Mengubah Posisi...
#  [ElemenGrafis id_elemen getter] Mengakses ID: KotakA
#  [Kotak posisi setter] Mencoba set posisi Kotak KotakA ke (50, 60)
#  [ElemenGrafis id_elemen getter] Mengakses ID: KotakA
#  -> Posisi Kotak KotakA berhasil diubah ke (50, 60)
# Mengakses Posisi Baru...
#  [ElemenGrafis id_elemen getter] Mengakses ID: KotakA
#  [Kotak posisi getter] Mengembalikan posisi Kotak KotakA: (50, 60)
# ------------------------------
# Mencoba Set Posisi Salah...
#  [ElemenGrafis id_elemen getter] Mengakses ID: KotakA
#  [Kotak posisi setter] Mencoba set posisi Kotak KotakA ke [100, 200]
#  -> Gagal: Posisi harus berupa tuple (x, y).
# ------------------------------
# Menggambar Kotak...
#  [ElemenGrafis id_elemen getter] Mengakses ID: KotakA
#  [Kotak gambar] Menggambar Kotak 'KotakA' warna Merah dengan ukuran 20x10 di (50, 60)
# ------------------------------
# Info Warna...
#  [ElemenGrafis id_elemen getter] Mengakses ID: KotakA
#  [ElemenGrafis info_warna] Warna elemen KotakA: Merah
# ------------------------------

# %% [markdown]
# ## PENUGASAN

# %%
# Tugas PBO - Hierarki Kelas Senjata dengan Abstract Base Class

from abc import ABC, abstractmethod

# a) Kelas Abstrak Senjata
class Senjata(ABC):
    def __init__(self, nama):
        """Konstruktor kelas abstrak Senjata"""
        self.nama = nama
    
    @abstractmethod
    def serang(self):
        """Metode abstrak untuk serangan"""
        pass
    
    @property
    @abstractmethod
    def daya_tahan(self):
        """Properti abstrak untuk daya tahan senjata"""
        pass
    
    # Metode konkret (opsional)
    def info_nama(self):
        """Metode konkret untuk menampilkan info nama senjata"""
        return f"Nama Senjata: {self.nama}"


# b) Kelas Anak Konkret 1: Pedang
class Pedang(Senjata):
    def __init__(self, nama, panjang_bilah):
        super().__init__(nama)
        self.panjang_bilah = panjang_bilah
        self._daya_tahan = 100  # Nilai tetap untuk daya tahan
    
    def serang(self):
        """Implementasi metode serang untuk Pedang"""
        print(f"⚔️  Pedang {self.nama} menebas dengan bilah sepanjang {self.panjang_bilah} cm!")
        self._daya_tahan -= 10
        print(f"   Daya tahan tersisa: {self._daya_tahan}")
    
    @property
    def daya_tahan(self):
        """Getter untuk properti daya_tahan"""
        return self._daya_tahan
    
    @daya_tahan.setter
    def daya_tahan(self, nilai):
        """Setter untuk properti daya_tahan"""
        if 0 <= nilai <= 100:
            self._daya_tahan = nilai
        else:
            print("Nilai daya tahan harus antara 0-100!")


# c) Kelas Anak Konkret 2: Panah
class Panah(Senjata):
    def __init__(self, nama, jumlah_anak_panah):
        super().__init__(nama)
        self._jumlah_anak_panah = jumlah_anak_panah
    
    def serang(self):
        """Implementasi metode serang untuk Panah"""
        if self._jumlah_anak_panah > 0:
            self._jumlah_anak_panah -= 1
            print(f"🏹  Panah {self.nama} melesat! Sisa anak panah: {self._jumlah_anak_panah}")
        else:
            print(f"❌  Amunisi Panah {self.nama} habis! Tidak bisa menyerang!")
    
    @property
    def daya_tahan(self):
        """Getter untuk properti daya_tahan (ammo)"""
        return self._jumlah_anak_panah
    
    @daya_tahan.setter
    def daya_tahan(self, nilai):
        """Setter untuk mengisi ulang anak panah"""
        if nilai >= 0:
            self._jumlah_anak_panah = nilai
            print(f"✅ Panah {self.nama} diisi ulang. Total: {self._jumlah_anak_panah} anak panah")
        else:
            print("Jumlah anak panah tidak boleh negatif!")


# d) Kode Utama
if __name__ == "__main__":
    print("=" * 60)
    print("PROGRAM DEMO HIERARKI KELAS SENJATA")
    print("=" * 60)
    
    # Membuat objek Pedang
    pedang_excalibur = Pedang("Excalibur", 85.5)
    print(f"\n📌 {pedang_excalibur.info_nama()}")
    print(f"   Panjang Bilah: {pedang_excalibur.panjang_bilah} cm")
    print(f"   Daya Tahan Awal: {pedang_excalibur.daya_tahan}")
    
    # Membuat objek Panah
    panah_legolas = Panah("Legolas Bow", 5)
    print(f"\n📌 {panah_legolas.info_nama()}")
    print(f"   Jumlah Anak Panah Awal: {panah_legolas.daya_tahan}")
    
    print("\n" + "=" * 60)
    print("DEMO SERANGAN PANAH (Pengurangan Amunisi)")
    print("=" * 60)
    
    # Memanggil serang() beberapa kali pada objek Panah
    for i in range(7):
        print(f"\nSerangan ke-{i+1}:")
        panah_legolas.serang()
    
    print("\n" + "=" * 60)
    print("DEMO SERANGAN PEDANG")
    print("=" * 60)
    
    # Memanggil serang() pada objek Pedang
    print("\nBeberapa kali serangan dengan Pedang:")
    for i in range(3):
        print(f"\nSerangan ke-{i+1}:")
        pedang_excalibur.serang()
    
    print("\n" + "=" * 60)
    print("DEMO AKSES PROPERTI ABSTRAK")
    print("=" * 60)
    
    # Akses properti abstrak
    print(f"\nDaya tahan Pedang {pedang_excalibur.nama}: {pedang_excalibur.daya_tahan}")
    print(f"Sisa amunisi Panah {panah_legolas.nama}: {panah_legolas.daya_tahan}")
    
    # Mengisi ulang panah menggunakan setter
    print(f"\nMengisi ulang panah...")
    panah_legolas.daya_tahan = 10
    print(f"Setelah diisi ulang: {panah_legolas.daya_tahan} anak panah")
    
    print("\n" + "=" * 60)
    print("DEMO KEAMANAN ABSTRACT CLASS")
    print("=" * 60)
    
    # Opsional: Mencoba membuat objek dari kelas abstrak
    try:
        senjata_abstrak = Senjata("Senjata Umum")
        print("Berhasil membuat objek Senjata")  # Tidak akan dieksekusi
    except TypeError as e:
        print(f"\n❌ TypeError: {e}")
        print("   (Tidak bisa membuat objek dari kelas abstrak Senjata - sesuai yang diharapkan)")
    
    print("\n" + "=" * 60)
    print("PROGRAM SELESAI")
    print("=" * 60)
# Out:
# ============================================================
# PROGRAM DEMO HIERARKI KELAS SENJATA
# ============================================================
#
# 📌 Nama Senjata: Excalibur
#    Panjang Bilah: 85.5 cm
#    Daya Tahan Awal: 100
#
# 📌 Nama Senjata: Legolas Bow
#    Jumlah Anak Panah Awal: 5
#
# ============================================================
# DEMO SERANGAN PANAH (Pengurangan Amunisi)
# ============================================================
#
# Serangan ke-1:
# 🏹  Panah Legolas Bow melesat! Sisa anak panah: 4
#
# Serangan ke-2:
# 🏹  Panah Legolas Bow melesat! Sisa anak panah: 3
#
# Serangan ke-3:
# 🏹  Panah Legolas Bow melesat! Sisa anak panah: 2
#
# Serangan ke-4:
# 🏹  Panah Legolas Bow melesat! Sisa anak panah: 1
#
# Serangan ke-5:
# 🏹  Panah Legolas Bow melesat! Sisa anak panah: 0
#
# Serangan ke-6:
# ❌  Amunisi Panah Legolas Bow habis! Tidak bisa menyerang!
#
# Serangan ke-7:
# ❌  Amunisi Panah Legolas Bow habis! Tidak bisa menyerang!
#
# ============================================================
# DEMO SERANGAN PEDANG
# ============================================================
#
# Beberapa kali serangan dengan Pedang:
#
# Serangan ke-1:
# ⚔️  Pedang Excalibur menebas dengan bilah sepanjang 85.5 cm!
#    Daya tahan tersisa: 90
#
# Serangan ke-2:
# ⚔️  Pedang Excalibur menebas dengan bilah sepanjang 85.5 cm!
#    Daya tahan tersisa: 80
#
# Serangan ke-3:
# ⚔️  Pedang Excalibur menebas dengan bilah sepanjang 85.5 cm!
#    Daya tahan tersisa: 70
#
# ============================================================
# DEMO AKSES PROPERTI ABSTRAK
# ============================================================
#
# Daya tahan Pedang Excalibur: 70
# Sisa amunisi Panah Legolas Bow: 0
#
# Mengisi ulang panah...
# ✅ Panah Legolas Bow diisi ulang. Total: 10 anak panah
# Setelah diisi ulang: 10 anak panah
#
# ============================================================
# DEMO KEAMANAN ABSTRACT CLASS
# ============================================================
#
# ❌ TypeError: Can't instantiate abstract class Senjata with abstract methods daya_tahan, serang
#    (Tidak bisa membuat objek dari kelas abstrak Senjata - sesuai yang diharapkan)
#
# ============================================================
# PROGRAM SELESAI
# ============================================================

# %%
> **Catatan:**
>
> Kode PlantUML tidak bisa langsung dijalankan di cell Python Jupyter Notebook. Untuk menampilkan diagram, Anda bisa:
>
> 1. Copy kode PlantUML ke layanan online seperti [PlantUML Online Server](https://www.plantuml.com/plantuml/).
> 2. Atau install ekstensi PlantUML di VS Code, lalu render file `.puml`.
> 3. Jika ingin menampilkan gambar di notebook, generate diagram di PlantUML, lalu download gambarnya dan masukkan ke notebook sebagai gambar.
>
> Berikut kode PlantUML yang sudah benar untuk hierarki Senjata:
>
> ```plantuml
> @startuml
> skinparam classAttributeIconSize 0
>
> abstract class Senjata {
>     +nama: String
>     +__init__(nama: String)
>     +{abstract} serang()
>     +{abstract} daya_tahan: int
>     +info_nama()
> }
>
> class Pedang {
>     +panjang_bilah: float
>     -_daya_tahan: int
>     +__init__(nama, panjang_bilah)
>     +serang()
>     +daya_tahan: int
> }
>
> class Panah {
>     -_jumlah_anak_panah: int
>     +__init__(nama, jumlah_anak_panah)
>     +serang()
>     +daya_tahan: int
> }
>
> Senjata <|-- Pedang
> Senjata <|-- Panah
> @enduml
> ```
# Out:
#   Cell In[1], line 2
#     skinparam classAttributeIconSize 0
#     ^
# SyntaxError: invalid syntax
